# %%
import pandas as pd
from clustergrammer_widget import *
from omics_tools import differential_expression, annotate_GO_KEGG, utils, comparison_generator

# %%
ginkgo_data = 'Reordered_ReadCountMatrix_preCAD.csv'

# %% [markdown]
# ### Fix some aspects of the dataframe, like category type and value

# %%
ginkgo_df = pd.read_csv(ginkgo_data, index_col=0, header=None, low_memory=False).T
ginkgo_df['strain'] = [x.split('/')[-2].replace('_','') for x in ginkgo_df['strain'].values]
ginkgo_df.rename(columns={'timepoint':'Timepoint', 'temp': 'Temp'}, inplace=True)
ginkgo_df['IPTG'] = ginkgo_df['IPTG'].replace(' NA', 0)
ginkgo_df['IPTG'] = ginkgo_df['IPTG'].astype(bool)
ginkgo_df['Arabinose'] = ginkgo_df['Arabinose'].replace(' NA', 0)
ginkgo_df['Arabinose'] = ginkgo_df['Arabinose'].astype(bool)
ginkgo_df['Timepoint'] = ginkgo_df['Timepoint'].replace(regex=':hour', value='')
ginkgo_df['Temp'] = ginkgo_df['Temp'].replace(regex=':celsius', value='')
ginkgo_df.drop(['GinkgoID','R1','R2','filename','flags','library','gene_id'], axis=1, inplace=True)
for x in ['Temp', 'Timepoint']:
    ginkgo_df[x] = pd.to_numeric(ginkgo_df[x]).astype('int64')

# %%
ginkgo_df.head(4)
# Out:
# 0                        strain  Temp replicate   IPTG  Arabinose  Timepoint  \
# 1  Strain3MG1655GenomicIcaRGate    37         0  False      False         18
# 2  Strain3MG1655GenomicIcaRGate    37         1  False      False         18
# 3  Strain3MG1655GenomicIcaRGate    37         2  False      False         18
# 4  Strain3MG1655GenomicIcaRGate    37         3  False      False         18
#
# 0 Actuator_YFP CamR Sensor_AraC Sensor_LacI  ... insI1 insH1 insE1 insF1  \
# 1         2214  302          36          24  ...    84   659    43    71
# 2         3333  532          48          37  ...   104  1026    72   121
# 3         3762  559          76          56  ...   133  1393    79   206
# 4         3059  484          46          42  ...    98  1006    54   141
#
# 0 insC1 insD1 insQ insJ insK insG
# 1   153   134   29    1    0   21
# 2   179   193   41    4    1   42
# 3   206   199   58    3    0   34
# 4   189   172   48    2    1   32
#
# [4 rows x 4116 columns]

# %% [markdown]
# ### Set up the two main components which determin the comparison logic
# #### the sub factors are the names of columns in the dataframe that define metadata for each sample
# #### the DE_tests list has each comparison we want to construct differential tests for

# %%
sub_factors = ['Timepoint', 'Temp', 'Arabinose', 'IPTG']
DE_tests = [
    ['Strain1MG1655WT', 'Strain1MG1655WT'],
    ['Strain1MG1655WT', 'Strain2MG1655GenomicPhlFGate'], #WT vs all
    ['Strain1MG1655WT', 'Strain3MG1655GenomicIcaRGate'], 
    ['Strain1MG1655WT', 'Strain4MG1655GenomicNANDCircuit'],
    ['Strain4MG1655GenomicNANDCircuit', 'Strain3MG1655GenomicIcaRGate'], #NAND vs IcaR genome
    ['Strain4MG1655GenomicNANDCircuit', 'Strain2MG1655GenomicPhlFGate'], #NAND vs PhlF genome
    ['Strain4MG1655GenomicNANDCircuit', 'Strain4MG1655GenomicNANDCircuit']  #NAND vs NAND
]

# %% [markdown]
# ### This sets up the commands to run in R by one of the two options further below

# %%
groups_array = utils.group_by_factors(ginkgo_df, ['strain']+sub_factors)
comparison_indices = comparison_generator.generate_comparisons(ginkgo_df, DE_tests, ['strain'], sub_factors, 1)
contrast_strings = differential_expression.make_contrast_strings(comparison_indices, groups_array)

# %% [markdown]
# ### Option 1: run everything in python multiprocesssed (will take hours)

# %%
r_cmds = differential_expression.make_DE_cmds(
    dataframe = ginkgo_df, 
    base_comparisons = DE_tests, 
    sub_factors = sub_factors)
print('Created {0} differential tests'.format(len(r_cmds)))
# Out:
# Created 112 differential tests

# %%
deg_results = differential_expression.run_edgeR(r_cmds, cores=8)

# %% [markdown]
# ### Option 2: generate script files in a directory ./scripts/ to transfer and run on HPC

# %%
differential_expression.make_hpc_de_files(
    dataframe=ginkgo_df,
    base_comparisons=DE_tests,
    sub_factors=sub_factors,
    run_dir='/btl/foundry/users/alex/20190228_novel_chassis/run_DGE/')
# Out:
# 0

# %%
# Bring the results back into python
deg_results = utils.load_DE_results('/Users/acristo/build/omics_tools/examples/results/')

# %% [markdown]
# ### Run the annotations

# %%
KEGG_df = annotate_GO_KEGG.run_kegg(deg_results)

# %%
import pickle
with open('kegg_results.pkl', 'wb') as f:
    pickle.dump(KEGG_df, f)

# %%
import pickle
with open('kegg_results.pkl', 'rb') as f:
    KEGG_df = pickle.load(f)

# %%
GO_df = annotate_GO_KEGG.run_go(deg_results)
# Out:
# INFO: downloading gene2go
# INFO: extracting
# INFO: complete
# INFO: Downloading bacteria gene info
# INFO: extracting
# INFO: complete
# INFO: downloading GO graph
# INFO: complete
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
#  78%  3,553 of  4,567 population items found in association
#  78%  3,553 of  4,567 population items found in association
#  78%  3,553 of  4,567 population items found in association
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# 100%      7 of      7 study items found in association
# 100%      7 of      7 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       29 GO terms are associated with      7 of      7 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
# 100%      4 of      4 study items found in association
# 100%      4 of      4 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       10 GO terms are associated with      4 of      4 study items
#        3 GO terms found significant (< 0.05=alpha) (  3 enriched +   0 purified): statsmodels fdr_bh
#  84%    119 of    142 study items found in association
# 100%    142 of    142 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      274 GO terms are associated with    119 of    142 study items
#       24 GO terms found significant (< 0.05=alpha) ( 24 enriched +   0 purified): statsmodels fdr_bh
#  90%     70 of     78 study items found in association
# 100%     78 of     78 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      223 GO terms are associated with     70 of     78 study items
#        6 GO terms found significant (< 0.05=alpha) (  6 enriched +   0 purified): statsmodels fdr_bh
#  85%    571 of    671 study items found in association
# 100%    671 of    671 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,062 GO terms are associated with    571 of    671 study items
#  94%  1,045 of  1,117 study items found in association
# 100%  1,117 of  1,117 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#        2 GO terms found significant (< 0.05=alpha) (  2 enriched +   0 purified): statsmodels fdr_bh
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,714 GO terms are associated with  1,045 of  1,117 study items
#  93%    772 of    828 study items found in association
# 100%    828 of    828 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#       23 GO terms found significant (< 0.05=alpha) ( 23 enriched +   0 purified): statsmodels fdr_bh
#  87%    782 of    903 study items found in association
# 100%    903 of    903 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,390 GO terms are associated with    772 of    828 study items
#       17 GO terms found significant (< 0.05=alpha) ( 17 enriched +   0 purified): statsmodels fdr_bh
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,355 GO terms are associated with    782 of    903 study items
#  83%      5 of      6 study items found in association
# 100%      6 of      6 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#        6 GO terms found significant (< 0.05=alpha) (  5 enriched +   1 purified): statsmodels fdr_bh
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       22 GO terms are associated with      5 of      6 study items
#  83%    394 of    472 study items found in association
# 100%    472 of    472 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#  50%      1 of      2 study items found in association
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      803 GO terms are associated with    394 of    472 study items
# 100%      2 of      2 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#  94%  1,105 of  1,176 study items found in association
# 100%  1,176 of  1,176 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#        3 GO terms found significant (< 0.05=alpha) (  3 enriched +   0 purified): statsmodels fdr_bh
#  93%     13 of     14 study items found in association
# 100%     14 of     14 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#  90%    501 of    558 study items found in association
# 100%    558 of    558 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,761 GO terms are associated with  1,105 of  1,176 study items
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       50 GO terms are associated with     13 of     14 study items
#       27 GO terms found significant (< 0.05=alpha) ( 27 enriched +   0 purified): statsmodels fdr_bh
#        3 GO terms found significant (< 0.05=alpha) (  3 enriched +   0 purified): statsmodels fdr_bh
#  84%    995 of  1,187 study items found in association
# 100%  1,187 of  1,187 study items found in population(4567)
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#        5 GO terms are associated with      1 of      2 study items
# Calculating 3,408 uncorrected p-values using fisher
#  83%      5 of      6 study items found in association
# 100%      6 of      6 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      945 GO terms are associated with    501 of    558 study items
#        5 GO terms found significant (< 0.05=alpha) (  5 enriched +   0 purified): statsmodels fdr_bh
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       29 GO terms are associated with      5 of      6 study items
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,516 GO terms are associated with    995 of  1,187 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        7 GO terms found significant (< 0.05=alpha) (  5 enriched +   2 purified): statsmodels fdr_bh
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
#  98%     53 of     54 study items found in association
# 100%     54 of     54 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      128 GO terms are associated with     53 of     54 study items
#       19 GO terms found significant (< 0.05=alpha) ( 19 enriched +   0 purified): statsmodels fdr_bh
#  95%     63 of     66 study items found in association
# 100%     66 of     66 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      212 GO terms are associated with     63 of     66 study items
#        2 GO terms found significant (< 0.05=alpha) (  2 enriched +   0 purified): statsmodels fdr_bh
#  78%  3,553 of  4,567 population items found in association
#  78%  3,553 of  4,567 population items found in association
#  78%  3,553 of  4,567 population items found in association
#  98%     49 of     50 study items found in association
# 100%     50 of     50 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#  98%     53 of     54 study items found in association
# 100%     54 of     54 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      186 GO terms are associated with     49 of     50 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#  92%     11 of     12 study items found in association
# 100%     12 of     12 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      188 GO terms are associated with     53 of     54 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#  98%    172 of    175 study items found in association
# 100%    175 of    175 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       47 GO terms are associated with     11 of     12 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#  96%    219 of    229 study items found in association
# 100%    229 of    229 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      446 GO terms are associated with    172 of    175 study items
#       25 GO terms found significant (< 0.05=alpha) ( 25 enriched +   0 purified): statsmodels fdr_bh
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      606 GO terms are associated with    219 of    229 study items
#       18 GO terms found significant (< 0.05=alpha) ( 18 enriched +   0 purified): statsmodels fdr_bh
#  90%    234 of    260 study items found in association
# 100%    260 of    260 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      620 GO terms are associated with    234 of    260 study items
#       20 GO terms found significant (< 0.05=alpha) ( 20 enriched +   0 purified): statsmodels fdr_bh
#  92%     12 of     13 study items found in association
# 100%     13 of     13 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       49 GO terms are associated with     12 of     13 study items
#        4 GO terms found significant (< 0.05=alpha) (  4 enriched +   0 purified): statsmodels fdr_bh
# 100%      2 of      2 study items found in association
# 100%      2 of      2 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       12 GO terms are associated with      2 of      2 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#  86%     12 of     14 study items found in association
# 100%     14 of     14 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       35 GO terms are associated with     12 of     14 study items
#        4 GO terms found significant (< 0.05=alpha) (  4 enriched +   0 purified): statsmodels fdr_bh
#  84%    415 of    493 study items found in association
# 100%    493 of    493 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      784 GO terms are associated with    415 of    493 study items
#        3 GO terms found significant (< 0.05=alpha) (  3 enriched +   0 purified): statsmodels fdr_bh
#  91%    538 of    594 study items found in association
# 100%    594 of    594 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#  85%    851 of  1,002 study items found in association
# 100%  1,002 of  1,002 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      997 GO terms are associated with    538 of    594 study items
#       12 GO terms found significant (< 0.05=alpha) ( 12 enriched +   0 purified): statsmodels fdr_bh
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,378 GO terms are associated with    851 of  1,002 study items
#        4 GO terms found significant (< 0.05=alpha) (  3 enriched +   1 purified): statsmodels fdr_bh
#  93%  1,096 of  1,174 study items found in association
# 100%  1,174 of  1,174 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,767 GO terms are associated with  1,096 of  1,174 study items
#       25 GO terms found significant (< 0.05=alpha) ( 25 enriched +   0 purified): statsmodels fdr_bh
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# 100%      4 of      4 study items found in association
# 100%      4 of      4 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       26 GO terms are associated with      4 of      4 study items
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
# 100%      5 of      5 study items found in association
# 100%      5 of      5 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       36 GO terms are associated with      5 of      5 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
#  78%  3,553 of  4,567 population items found in association
#  83%    364 of    438 study items found in association
# 100%    438 of    438 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      709 GO terms are associated with    364 of    438 study items
#  88%     75 of     85 study items found in association
# 100%     85 of     85 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#        3 GO terms found significant (< 0.05=alpha) (  3 enriched +   0 purified): statsmodels fdr_bh
#  90%    430 of    479 study items found in association
# 100%    479 of    479 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      224 GO terms are associated with     75 of     85 study items
#        3 GO terms found significant (< 0.05=alpha) (  3 enriched +   0 purified): statsmodels fdr_bh
#  86%     44 of     51 study items found in association
# 100%     51 of     51 study items found in population(4567)
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      790 GO terms are associated with    430 of    479 study items
# Calculating 3,408 uncorrected p-values using fisher
#        5 GO terms found significant (< 0.05=alpha) (  5 enriched +   0 purified): statsmodels fdr_bh
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      141 GO terms are associated with     44 of     51 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#  94%  1,056 of  1,120 study items found in association
# 100%  1,120 of  1,120 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,714 GO terms are associated with  1,056 of  1,120 study items
#       24 GO terms found significant (< 0.05=alpha) ( 24 enriched +   0 purified): statsmodels fdr_bh
#  85%    835 of    986 study items found in association
# 100%    986 of    986 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,374 GO terms are associated with    835 of    986 study items
#        4 GO terms found significant (< 0.05=alpha) (  3 enriched +   1 purified): statsmodels fdr_bh
# 100%      3 of      3 study items found in association
# 100%      3 of      3 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       13 GO terms are associated with      3 of      3 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#  84%    336 of    401 study items found in association
# 100%    401 of    401 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      688 GO terms are associated with    336 of    401 study items
#        8 GO terms found significant (< 0.05=alpha) (  8 enriched +   0 purified): statsmodels fdr_bh
#  89%    377 of    424 study items found in association
# 100%    424 of    424 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      714 GO terms are associated with    377 of    424 study items
#        8 GO terms found significant (< 0.05=alpha) (  8 enriched +   0 purified): statsmodels fdr_bh
# 100%     15 of     15 study items found in association
# 100%     15 of     15 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       42 GO terms are associated with     15 of     15 study items
#        6 GO terms found significant (< 0.05=alpha) (  6 enriched +   0 purified): statsmodels fdr_bh
# 100%     10 of     10 study items found in association
# 100%     10 of     10 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       36 GO terms are associated with     10 of     10 study items
#        4 GO terms found significant (< 0.05=alpha) (  4 enriched +   0 purified): statsmodels fdr_bh
# 100%     32 of     32 study items found in association
# 100%     32 of     32 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       94 GO terms are associated with     32 of     32 study items
#       11 GO terms found significant (< 0.05=alpha) ( 11 enriched +   0 purified): statsmodels fdr_bh
# 100%      3 of      3 study items found in association
# 100%      3 of      3 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       19 GO terms are associated with      3 of      3 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
#  84%    360 of    430 study items found in association
# 100%    430 of    430 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      709 GO terms are associated with    360 of    430 study items
#        9 GO terms found significant (< 0.05=alpha) (  9 enriched +   0 purified): statsmodels fdr_bh
#  90%    415 of    460 study items found in association
# 100%    460 of    460 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      779 GO terms are associated with    415 of    460 study items
#        9 GO terms found significant (< 0.05=alpha) (  9 enriched +   0 purified): statsmodels fdr_bh
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
#  83%     10 of     12 study items found in association
# 100%     12 of     12 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       52 GO terms are associated with     10 of     12 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#  82%      9 of     11 study items found in association
# 100%     11 of     11 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       37 GO terms are associated with      9 of     11 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
#  92%    717 of    782 study items found in association
# 100%    782 of    782 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,318 GO terms are associated with    717 of    782 study items
#        7 GO terms found significant (< 0.05=alpha) (  7 enriched +   0 purified): statsmodels fdr_bh
#  86%    596 of    697 study items found in association
# 100%    697 of    697 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,137 GO terms are associated with    596 of    697 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#  84%  1,015 of  1,206 study items found in association
# 100%  1,206 of  1,206 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,555 GO terms are associated with  1,015 of  1,206 study items
#        2 GO terms found significant (< 0.05=alpha) (  2 enriched +   0 purified): statsmodels fdr_bh
#  94%  1,175 of  1,254 study items found in association
# 100%  1,254 of  1,254 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,822 GO terms are associated with  1,175 of  1,254 study items
#       31 GO terms found significant (< 0.05=alpha) ( 30 enriched +   1 purified): statsmodels fdr_bh
#  92%    880 of    953 study items found in association
# 100%    953 of    953 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,461 GO terms are associated with    880 of    953 study items
#       37 GO terms found significant (< 0.05=alpha) ( 37 enriched +   0 purified): statsmodels fdr_bh
#  85%    529 of    625 study items found in association
# 100%    625 of    625 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      957 GO terms are associated with    529 of    625 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#  93%  1,061 of  1,135 study items found in association
# 100%  1,135 of  1,135 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,729 GO terms are associated with  1,061 of  1,135 study items
#       27 GO terms found significant (< 0.05=alpha) ( 27 enriched +   0 purified): statsmodels fdr_bh
#  86%    891 of  1,042 study items found in association
# 100%  1,042 of  1,042 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,439 GO terms are associated with    891 of  1,042 study items
#        4 GO terms found significant (< 0.05=alpha) (  3 enriched +   1 purified): statsmodels fdr_bh
#  86%    152 of    177 study items found in association
# 100%    177 of    177 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      319 GO terms are associated with    152 of    177 study items
#       20 GO terms found significant (< 0.05=alpha) ( 20 enriched +   0 purified): statsmodels fdr_bh
#  84%     53 of     63 study items found in association
# 100%     63 of     63 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      158 GO terms are associated with     53 of     63 study items
#        4 GO terms found significant (< 0.05=alpha) (  4 enriched +   0 purified): statsmodels fdr_bh
#  50%      1 of      2 study items found in association
# 100%      2 of      2 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#        4 GO terms are associated with      1 of      2 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
# 100%     16 of     16 study items found in association
# 100%     16 of     16 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       47 GO terms are associated with     16 of     16 study items
#        4 GO terms found significant (< 0.05=alpha) (  4 enriched +   0 purified): statsmodels fdr_bh
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# 100%      2 of      2 study items found in association
# 100%      2 of      2 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       11 GO terms are associated with      2 of      2 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
# 100%      5 of      5 study items found in association
# 100%      5 of      5 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       24 GO terms are associated with      5 of      5 study items
#        2 GO terms found significant (< 0.05=alpha) (  2 enriched +   0 purified): statsmodels fdr_bh
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
#  88%     65 of     74 study items found in association
# 100%     74 of     74 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      235 GO terms are associated with     65 of     74 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#  98%     81 of     83 study items found in association
# 100%     83 of     83 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      262 GO terms are associated with     81 of     83 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
#  89%    177 of    199 study items found in association
# 100%    199 of    199 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      394 GO terms are associated with    177 of    199 study items
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#  96%    131 of    137 study items found in association
# 100%    137 of    137 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      372 GO terms are associated with    131 of    137 study items
#        8 GO terms found significant (< 0.05=alpha) (  8 enriched +   0 purified): statsmodels fdr_bh
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
#  87%    137 of    157 study items found in association
# 100%    157 of    157 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      373 GO terms are associated with    137 of    157 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#  96%    185 of    193 study items found in association
# 100%    193 of    193 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      546 GO terms are associated with    185 of    193 study items
#       20 GO terms found significant (< 0.05=alpha) ( 19 enriched +   1 purified): statsmodels fdr_bh
#  84%  1,095 of  1,299 study items found in association
# 100%  1,299 of  1,299 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,591 GO terms are associated with  1,095 of  1,299 study items
#        7 GO terms found significant (< 0.05=alpha) (  5 enriched +   2 purified): statsmodels fdr_bh
#  94%  1,235 of  1,308 study items found in association
# 100%  1,308 of  1,308 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,854 GO terms are associated with  1,235 of  1,308 study items
#       33 GO terms found significant (< 0.05=alpha) ( 31 enriched +   2 purified): statsmodels fdr_bh
#  91%    130 of    143 study items found in association
# 100%    143 of    143 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      293 GO terms are associated with    130 of    143 study items
#       26 GO terms found significant (< 0.05=alpha) ( 26 enriched +   0 purified): statsmodels fdr_bh
#  74%     63 of     85 study items found in association
# 100%     85 of     85 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      174 GO terms are associated with     63 of     85 study items
#        7 GO terms found significant (< 0.05=alpha) (  6 enriched +   1 purified): statsmodels fdr_bh
#  94%     58 of     62 study items found in association
# 100%     62 of     62 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      186 GO terms are associated with     58 of     62 study items
#        2 GO terms found significant (< 0.05=alpha) (  2 enriched +   0 purified): statsmodels fdr_bh
#  80%     35 of     44 study items found in association
# 100%     44 of     44 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      106 GO terms are associated with     35 of     44 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
#  84%    467 of    558 study items found in association
# 100%    558 of    558 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      831 GO terms are associated with    467 of    558 study items
#       17 GO terms found significant (< 0.05=alpha) ( 17 enriched +   0 purified): statsmodels fdr_bh
#  93%    314 of    336 study items found in association
# 100%    336 of    336 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      630 GO terms are associated with    314 of    336 study items
#       33 GO terms found significant (< 0.05=alpha) ( 33 enriched +   0 purified): statsmodels fdr_bh
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  94%     31 of     33 study items found in association
# 100%     33 of     33 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#  78%  3,553 of  4,567 population items found in association
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      102 GO terms are associated with     31 of     33 study items
#        3 GO terms found significant (< 0.05=alpha) (  3 enriched +   0 purified): statsmodels fdr_bh
#  88%     29 of     33 study items found in association
# 100%     33 of     33 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#  84%     82 of     98 study items found in association
# 100%     98 of     98 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       87 GO terms are associated with     29 of     33 study items
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      177 GO terms are associated with     82 of     98 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        4 GO terms found significant (< 0.05=alpha) (  4 enriched +   0 purified): statsmodels fdr_bh
#  93%    178 of    192 study items found in association
# 100%    192 of    192 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      479 GO terms are associated with    178 of    192 study items
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  85%    323 of    380 study items found in association
# 100%    380 of    380 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#  78%  3,553 of  4,567 population items found in association
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      687 GO terms are associated with    323 of    380 study items
#        5 GO terms found significant (< 0.05=alpha) (  5 enriched +   0 purified): statsmodels fdr_bh
#  91%    372 of    407 study items found in association
# 100%    407 of    407 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      764 GO terms are associated with    372 of    407 study items
#        7 GO terms found significant (< 0.05=alpha) (  7 enriched +   0 purified): statsmodels fdr_bh
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
#  89%    588 of    664 study items found in association
# 100%    664 of    664 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,120 GO terms are associated with    588 of    664 study items
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#  93%    527 of    568 study items found in association
# 100%    568 of    568 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,035 GO terms are associated with    527 of    568 study items
#       11 GO terms found significant (< 0.05=alpha) ( 11 enriched +   0 purified): statsmodels fdr_bh
# 100%      3 of      3 study items found in association
# 100%      3 of      3 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       18 GO terms are associated with      3 of      3 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
# 100%      5 of      5 study items found in association
# 100%      5 of      5 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       21 GO terms are associated with      5 of      5 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
# 100%      3 of      3 study items found in association
# 100%      3 of      3 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       21 GO terms are associated with      3 of      3 study items
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#  92%     92 of    100 study items found in association
# 100%    100 of    100 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      245 GO terms are associated with     92 of    100 study items
#       26 GO terms found significant (< 0.05=alpha) ( 26 enriched +   0 purified): statsmodels fdr_bh
#  75%     38 of     51 study items found in association
# 100%     51 of     51 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      107 GO terms are associated with     38 of     51 study items
#        3 GO terms found significant (< 0.05=alpha) (  3 enriched +   0 purified): statsmodels fdr_bh
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
#  99%    174 of    175 study items found in association
# 100%    175 of    175 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      506 GO terms are associated with    174 of    175 study items
#       27 GO terms found significant (< 0.05=alpha) ( 27 enriched +   0 purified): statsmodels fdr_bh
#  95%     55 of     58 study items found in association
# 100%     58 of     58 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      218 GO terms are associated with     55 of     58 study items
#        4 GO terms found significant (< 0.05=alpha) (  4 enriched +   0 purified): statsmodels fdr_bh
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# ...
#  83%      5 of      6 study items found in association
# 100%      6 of      6 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       13 GO terms are associated with      5 of      6 study items
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
# 100%     11 of     11 study items found in association
# 100%     11 of     11 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       39 GO terms are associated with     11 of     11 study items
#        4 GO terms found significant (< 0.05=alpha) (  4 enriched +   0 purified): statsmodels fdr_bh
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
#  93%  1,139 of  1,225 study items found in association
# 100%  1,225 of  1,225 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,795 GO terms are associated with  1,139 of  1,225 study items
#       22 GO terms found significant (< 0.05=alpha) ( 22 enriched +   0 purified): statsmodels fdr_bh
#  84%    890 of  1,062 study items found in association
# 100%  1,062 of  1,062 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,399 GO terms are associated with    890 of  1,062 study items
#        2 GO terms found significant (< 0.05=alpha) (  1 enriched +   1 purified): statsmodels fdr_bh
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
#  81%    175 of    215 study items found in association
# 100%    215 of    215 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      419 GO terms are associated with    175 of    215 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#  94%    458 of    488 study items found in association
# 100%    488 of    488 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,017 GO terms are associated with    458 of    488 study items
#       19 GO terms found significant (< 0.05=alpha) ( 19 enriched +   0 purified): statsmodels fdr_bh
#  93%    932 of    998 study items found in association
# 100%    998 of    998 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,576 GO terms are associated with    932 of    998 study items
#       25 GO terms found significant (< 0.05=alpha) ( 24 enriched +   1 purified): statsmodels fdr_bh
#  85%    776 of    908 study items found in association
# 100%    908 of    908 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,233 GO terms are associated with    776 of    908 study items
#       12 GO terms found significant (< 0.05=alpha) ( 11 enriched +   1 purified): statsmodels fdr_bh
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# 100%      7 of      7 study items found in association
# 100%      7 of      7 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       44 GO terms are associated with      7 of      7 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#  89%      8 of      9 study items found in association
# 100%      9 of      9 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       29 GO terms are associated with      8 of      9 study items
#        2 GO terms found significant (< 0.05=alpha) (  2 enriched +   0 purified): statsmodels fdr_bh
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# 100%      3 of      3 study items found in association
# 100%      3 of      3 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       15 GO terms are associated with      3 of      3 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
# 100%      2 of      2 study items found in association
# 100%      2 of      2 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       20 GO terms are associated with      2 of      2 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
#  97%     28 of     29 study items found in association
# 100%     29 of     29 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      104 GO terms are associated with     28 of     29 study items
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#  96%     25 of     26 study items found in association
# 100%     26 of     26 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      112 GO terms are associated with     25 of     26 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
#  86%    744 of    865 study items found in association
# 100%    865 of    865 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,228 GO terms are associated with    744 of    865 study items
#       10 GO terms found significant (< 0.05=alpha) (  9 enriched +   1 purified): statsmodels fdr_bh
#  92%    883 of    961 study items found in association
# 100%    961 of    961 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,495 GO terms are associated with    883 of    961 study items
#       21 GO terms found significant (< 0.05=alpha) ( 21 enriched +   0 purified): statsmodels fdr_bh
#  92%  1,055 of  1,144 study items found in association
# 100%  1,144 of  1,144 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,725 GO terms are associated with  1,055 of  1,144 study items
#       17 GO terms found significant (< 0.05=alpha) ( 16 enriched +   1 purified): statsmodels fdr_bh
#  86%    915 of  1,067 study items found in association
# 100%  1,067 of  1,067 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,448 GO terms are associated with    915 of  1,067 study items
#        1 GO terms found significant (< 0.05=alpha) (  0 enriched +   1 purified): statsmodels fdr_bh
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
#  92%  1,041 of  1,128 study items found in association
# 100%  1,128 of  1,128 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,687 GO terms are associated with  1,041 of  1,128 study items
#       26 GO terms found significant (< 0.05=alpha) ( 22 enriched +   4 purified): statsmodels fdr_bh
#  86%    850 of    991 study items found in association
# 100%    991 of    991 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,379 GO terms are associated with    850 of    991 study items
#        2 GO terms found significant (< 0.05=alpha) (  1 enriched +   1 purified): statsmodels fdr_bh
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
#  81%    147 of    181 study items found in association
# 100%    181 of    181 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      351 GO terms are associated with    147 of    181 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#  94%    460 of    490 study items found in association
# 100%    490 of    490 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#    1,028 GO terms are associated with    460 of    490 study items
#       18 GO terms found significant (< 0.05=alpha) ( 18 enriched +   0 purified): statsmodels fdr_bh
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# 100%      1 of      1 study items found in association
# 100%      1 of      1 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#        7 GO terms are associated with      1 of      1 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
# 100%      1 of      1 study items found in association
# 100%      1 of      1 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#        4 GO terms are associated with      1 of      1 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#  86%    287 of    334 study items found in association
# 100%    334 of    334 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      583 GO terms are associated with    287 of    334 study items
#        5 GO terms found significant (< 0.05=alpha) (  5 enriched +   0 purified): statsmodels fdr_bh
#  89%    400 of    448 study items found in association
# 100%    448 of    448 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      774 GO terms are associated with    400 of    448 study items
#       12 GO terms found significant (< 0.05=alpha) ( 12 enriched +   0 purified): statsmodels fdr_bh
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
#  86%    142 of    166 study items found in association
# 100%    166 of    166 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      292 GO terms are associated with    142 of    166 study items
#       22 GO terms found significant (< 0.05=alpha) ( 22 enriched +   0 purified): statsmodels fdr_bh
#  92%     72 of     78 study items found in association
# 100%     78 of     78 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      249 GO terms are associated with     72 of     78 study items
#       10 GO terms found significant (< 0.05=alpha) ( 10 enriched +   0 purified): statsmodels fdr_bh
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/data/go-basic.obo: fmt(1.2) rel(2019-04-17) 47,398 GO Terms
#  78%  3,553 of  4,567 population items found in association
#  89%    148 of    167 study items found in association
# 100%    167 of    167 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      318 GO terms are associated with    148 of    167 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#  92%    153 of    167 study items found in association
# 100%    167 of    167 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#      378 GO terms are associated with    153 of    167 study items
#       10 GO terms found significant (< 0.05=alpha) ( 10 enriched +   0 purified): statsmodels fdr_bh
# 100%      3 of      3 study items found in association
# 100%      3 of      3 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       21 GO terms are associated with      3 of      3 study items
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#  73%      8 of     11 study items found in association
# 100%     11 of     11 study items found in population(4567)
# Calculating 3,408 uncorrected p-values using fisher
#    3,408 GO terms are associated with  3,553 of  4,567 population items
#       24 GO terms are associated with      8 of     11 study items
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh

# %%
import pickle
with open('go_results.pkl', 'wb') as f:
    pickle.dump(GO_df, f)

# %%
import pickle
with open('go_results.pkl', 'rb') as f:
    GO_df = pickle.load(f)

# %% [markdown]
# ### Combine annotations

# %%
anno_df = annotate_GO_KEGG.combine_annotations(GO_df, KEGG_df)

# %% [markdown]
# ### Map descriptions of GO/KEGG annotations and create clustergrammer dataframe

# %%
cg_file = 'new_results'
factor_to_categories = utils.get_factor_categories(sub_factors, ginkgo_df)
terms = annotate_GO_KEGG.functional_annotations(GO_df, KEGG_df)
utils.create_clustergrammer_matrix_file(
    annotated_dataframe = anno_df, 
    factor_to_categories = factor_to_categories,
    terms = terms, 
    fname = cg_file)

# %% [markdown]
# ### View clustergrammer matrix

# %%
net = Network(clustergrammer_widget)
net.load_file(cg_file + '.txt')
cgdf = net.export_df()
cgdf = utils.log10_conv(cgdf)
net.load_df(cgdf)
net.cluster(dist_type='euclidean')
net.widget()
# Out:
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/clustergrammer_widget/clustergrammer/load_data.py:70: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   tmp_df['mat'] = pd.read_table(file_buffer, index_col=row_arr)
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/utils.py:127: RuntimeWarning: divide by zero encountered in log10
#   x[x > 0] = -1*np.log10(x)
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/utils.py:127: RuntimeWarning: invalid value encountered in log10
#   x[x > 0] = -1*np.log10(x)
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/utils.py:128: RuntimeWarning: divide by zero encountered in log10
#   x[x < 0] = np.log10(-1*x)
# /Users/acristo/anaconda2/envs/test/lib/python3.6/site-packages/omics_tools/utils.py:128: RuntimeWarning: invalid value encountered in log10
#   x[x < 0] = np.log10(-1*x)
# clustergrammer_widget(network='{"row_nodes": [{"name": "Strain1MG1655WT_False_False_30_18-vs-Strain1MG1655WT_F…
